# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("melborn.csv")
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type    Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# ...

# %%
df.shape
# Out:
# (18396, 22)

# %%
df.nunique()
# Out:
# Unnamed: 0       18396
# Suburb             330
# Address          18134
# Rooms               11
# Type                 3
# Price             2470
# Method               5
# SellerG            305
# Date                58
# Distance           210
# Postcode           205
# Bedroom2            12
# Bathroom             9
# Car                 11
# Landsize          1449
# BuildingArea       613
# YearBuilt          144
# CouncilArea         33
# Lattitude         7518
# Longtitude        8168
# Regionname           8
# Propertycount      324
# dtype: int64

# %%
drop_cl = ["Address", "Date", "Postcode","YearBuilt","Lattitude", "Longtitude"]
df = df.drop(drop_cl, axis="columns")

# %%
df.head()
# Out:
#    Unnamed: 0      Suburb  Rooms Type    Price Method SellerG  Distance  \
# 0           1  Abbotsford      2    h  1480000      S  Biggin       2.5
# 1           2  Abbotsford      2    h  1035000      S  Biggin       2.5
# 2           4  Abbotsford      3    h  1465000     SP  Biggin       2.5
# 3           5  Abbotsford      3    h   850000     PI  Biggin       2.5
# 4           6  Abbotsford      4    h  1600000     VB  Nelson       2.5
#
#    Bedroom2  Bathroom  Car  Landsize  BuildingArea CouncilArea  \
# 0       2.0       1.0  1.0     202.0           NaN       Yarra
# 1       2.0       1.0  0.0     156.0          79.0       Yarra
# 2       3.0       2.0  0.0     134.0         150.0       Yarra
# 3       3.0       2.0  1.0      94.0           NaN       Yarra
# 4       3.0       1.0  2.0     120.0         142.0       Yarra
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# ...

# %%
df.shape
# Out:
# (18396, 16)

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# CouncilArea       6163
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
fill_cl = ["Distance", "Bedroom2", "Bathroom", "Car", "Propertycount"]
df[fill_cl] = df[fill_cl].fillna(0)
df.isna().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize          4793
# BuildingArea     10634
# CouncilArea       6163
# Regionname           1
# Propertycount        0
# dtype: int64

# %%
df["Landsize"] = df["Landsize"].fillna(df.Landsize.mean())
df["BuildingArea"] = df["BuildingArea"].fillna(df.BuildingArea.mean())

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Suburb              0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea      6163
# Regionname          1
# Propertycount       0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Unnamed: 0       0
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df = pd.get_dummies(df, drop_first=True)

# Convert True/False values to 0/1 integers
df = df.astype(int)
df.head()
# Out:
#    Unnamed: 0  Rooms    Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0           1      2  1480000         2         2         1    1       202
# 1           2      2  1035000         2         2         1    0       156
# 2           4      3  1465000         2         3         2    0       134
# 3           5      3   850000         2         3         2    1        94
# 4           6      4  1600000         2         3         1    2       120
#
#    BuildingArea  Propertycount  ...  CouncilArea_Wyndham  CouncilArea_Yarra  \
# 0           151           4019  ...                    0                  1
# 1            79           4019  ...                    0                  1
# 2           150           4019  ...                    0                  1
# 3           151           4019  ...                    0                  1
# 4           142           4019  ...                    0                  1
#
# ...

# %%
x = df.drop("Price",  axis=1)
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Cheaking Model Score

# %%
reg.score(test_x,test_y)
# Out:
# -1784079261869.9521

# %% [markdown]
# ## Model is Overfit

# %%
reg.score(train_x, train_y)
# Out:
# 0.7112864237496237

# %% [markdown]
# ## Import model Lasso L1

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha = 50, max_iter= 100, tol=0.1)
lasso_reg.fit(train_x, train_y)
# Out:
# C:\Users\Aakash\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.371e+14, tolerance: 3.538e+14
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(test_x, test_y)
# Out:
# 0.6720956773052591

# %%
lasso_reg.score(train_x, train_y)
# Out:
# 0.7071972122984274

# %% [markdown]
# ## Import Model Ridge L2

# %%
from sklearn import linear_model
ridge_reg = linear_model.Ridge(alpha = 50, max_iter= 100, tol=0.1)
ridge_reg.fit(train_x, train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(train_x,train_y)
# Out:
# 0.6775645256523584

# %%
ridge_reg.score(test_x, test_y)
# Out:
# 0.6622361365967822
