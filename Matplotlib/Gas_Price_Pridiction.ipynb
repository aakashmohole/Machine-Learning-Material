# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashmohole/Machine-Learning-Phase_1-/blob/main/Gas_Price_Pridiction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries ⚓
#
# ---

# %%
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

drive.mount('/content/drive', force_remount='true')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Line Graph -----
#
# ---

# %%
gas = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gas_prices.csv')

gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.title("Gas Price Over Time (in USD)",fontdict={'fontweight': 'bold','fontsize' : 15})
# plt.figure(figsize = (8,5),dpi=500)
#here we pass the year as x axis data and country as y axis

# first wau
plt.plot(gas.Year,gas.USA,'b.-', label = 'USA')
# second way
plt.plot(gas['Year'], gas.Canada, 'r.-',label = 'Canada')
# thired way
plt.plot(gas['Year'], gas['South Korea'],'g.-', label = 'South Korea')
plt.plot(gas.Year, gas.Australia,'y.-', label = 'Australia')

# plot the grap using for loop
# for country in gas:
#     if country != 'Year':
#         plt.plot(gas.Year, gas[country], marker='.')


# ploting graph using list
# country_to_lookat = ['Australia','Canada','France','Italy']
# for country in gas:
#     if country in country_to_lookat:
#         plt.plot(gas.Year, gas[country], marker='.')

plt.xticks(gas.Year[::3].tolist()+[2011]) # get data of every third Year
# print(gas.Year[::3])

plt.xlabel('Year')
plt.ylabel('US Dollers')
plt.legend()

plt.savefig('gas_price_figure.png',dpi = 300)
plt.show()
